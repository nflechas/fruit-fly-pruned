# %% [markdown]
# # 1 . Introduction

# %% [markdown]
# This notebook contains the results of the various experiments I ran with different hyperparameters

# %% [markdown]
# ## 2. Pruned embeddings

# %% [markdown]
# First, I perform a rather exhaustive search to get an idea, for each parameter, which neighood of values yields the best performance:
#
# proj_size: 6, 10, 15, 30, 45, 100
#
# kc_size: 11000, 3000, 5000, 10000, 20000
#
# wta: 20, 22, 25
#
# k (for PCA): None, 2, int(num_feats * 0.75)

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=2
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 231)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 231 KC LAYER: 1000
# SIZE OF PROJECTIONS: 6
# SIZE OF FINAL HASH: 2 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 231 1000 6 2
#       SPEARMAN BEFORE FLYING: 0.6501097960662927 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.5321866254923399 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 173 KC LAYER: 1000
# SIZE OF PROJECTIONS: 6
# SIZE OF FINAL HASH: 2 %
# NUM PCA COMPONENTS: 173
#      INIT FLY: 173 1000 6 2
#       SPEARMAN BEFORE FLYING: 0.7720155839514088 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.5681431277982315 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 231 KC LAYER: 1000
# SIZE OF PROJECTIONS: 6
# SIZE OF FINAL HASH: 5 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 231 1000 6 5
# ...

# %% [markdown]
# ### Hyperparameter subset
#
# After analysing the results, I chose a smaller subset of parameters for the rest of the experiments, such that obtaining results is quicker.
#
# proj_size: 15, 30, 45
#
# kc_size: 10000, 20000, 25000
#
# wta: 20, 22, 25
#
# k (for PCA): None, 2, int(num_feats * 0.75)

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=2
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 231)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 231 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 231 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.6501097960662927 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.7635673172768304 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.40728689204713775 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.22872792963004418 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 173 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 173
#      INIT FLY: 173 10000 15 20
# ...

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=3
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 143)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 143 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 143 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.6373776243324133 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.7383678626381701 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.39100887531601153 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.2148401364533342 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 107 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 107
#      INIT FLY: 107 10000 15 20
# ...

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=4
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 66)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 66 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 66 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.6137817003005533 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.6670770507937959 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.3226526551586304 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.2365361911645161 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 49 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 49
#      INIT FLY: 49 10000 15 20
# ...

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=5
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 27)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 27 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 27 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.5266265898124473 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.5858183787634246 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.27670228457032187 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.21032613068359762 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 20 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 20
#      INIT FLY: 20 10000 15 20
# ...

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=pruned --num_cat=6
# Out:
# /workspaces/fruit-fly-pruned/data/pruned_experiment/pca_pruning_feats_retained_per_cat.csv
# (751, 6)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 6 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 6 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.35178660440992715 (calculated over 3000 items.)
# /home/vscode/.local/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4881: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
#       SPEARMAN AFTER FLYING: nan (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.20554059203469502 (calculated over 3000 items.)
# ...

# %% [markdown]
# ## 3. Unpruned embeddings
#
# In this section, I ran the experiments using the unpruned matrix. I used the same parameters as in the previous section.

# %%
# !python3 pruned_fly_solution_pca.py --matrix_type=unpruned --num_cat=0
# Out:
# (751, 300)
# VOCAB SIZE: 751
# DIMENSIONALITY OF RAW SPACE: 751
# ***
# SIZES PN LAYER: 300 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: None
#      INIT FLY: 300 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.6589416303053981 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.7733088101695038 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 2 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 2
#      INIT FLY: 2 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.4184712685594115 (calculated over 3000 items.)
#       SPEARMAN AFTER FLYING: 0.2319897410448378 (calculated over 3000 items.)
# ***
# SIZES PN LAYER: 225 KC LAYER: 10000
# SIZE OF PROJECTIONS: 15
# SIZE OF FINAL HASH: 20 %
# NUM PCA COMPONENTS: 225
#      INIT FLY: 225 10000 15 20
#       SPEARMAN BEFORE FLYING: 0.7856854493996291 (calculated over 3000 items.)
# ...
